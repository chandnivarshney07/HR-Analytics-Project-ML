# %%
import pandas as pd   #imprting panda library for data analysis
import numpy as np    #importing numpy library for mathematical operations
import seaborn as sns #importing seaborn library for data visualization
import matplotlib.pyplot as plt  #matplotlib work like a MATLAB
import warnings
warnings.filterwarnings('ignore')
df=pd.read_csv('hrdataset.csv')
df
# Out:
#       Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 0     Female         0           No   Yes  Month-to-month      No    Yes   18
# 1     Female         0           No   Yes  Month-to-month      No    Yes   19
# 2       Male         0           No   Yes  Month-to-month     Yes     No   22
# 3     Female         1           No   Yes  Month-to-month     Yes    Yes   21
# 4       Male         0           No   Yes  Month-to-month     Yes    Yes   23
# ...      ...       ...          ...   ...             ...     ...    ...  ...
# 4995  Female         0           No   Yes  Month-to-month      No     No   72
# 4996    Male         0           No   Yes  Month-to-month     Yes     No   73
# 4997    Male         0           No   Yes  Month-to-month     Yes     No   74
# 4998    Male         1           No   Yes  Month-to-month     Yes    Yes   74
# 4999    Male         0          Yes   Yes        Two year     Yes     No   88
#
# ...

# %%
#doing deep copy to keep a copy of raw data for future references if needed
df1=df.copy()
df1
# Out:
#       Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 0     Female         0           No   Yes  Month-to-month      No    Yes   18
# 1     Female         0           No   Yes  Month-to-month      No    Yes   19
# 2       Male         0           No   Yes  Month-to-month     Yes     No   22
# 3     Female         1           No   Yes  Month-to-month     Yes    Yes   21
# 4       Male         0           No   Yes  Month-to-month     Yes    Yes   23
# ...      ...       ...          ...   ...             ...     ...    ...  ...
# 4995  Female         0           No   Yes  Month-to-month      No     No   72
# 4996    Male         0           No   Yes  Month-to-month     Yes     No   73
# 4997    Male         0           No   Yes  Month-to-month     Yes     No   74
# 4998    Male         1           No   Yes  Month-to-month     Yes    Yes   74
# 4999    Male         0          Yes   Yes        Two year     Yes     No   88
#
# ...

# %%
df.size
# Out:
# 100000

# %%
df.shape
# Out:
# (5000, 20)

# %%
df.head(10)
# Out:
#    Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 0  Female         0           No   Yes  Month-to-month      No    Yes   18
# 1  Female         0           No   Yes  Month-to-month      No    Yes   19
# 2    Male         0           No   Yes  Month-to-month     Yes     No   22
# 3  Female         1           No   Yes  Month-to-month     Yes    Yes   21
# 4    Male         0           No   Yes  Month-to-month     Yes    Yes   23
# 5    Male         0           No   Yes        Two year     Yes     No   23
# 6    Male         0          Yes    No        Two year     Yes     No   23
# 7  Female         0           No   Yes        One year     Yes     No   24
# 8  Female         1           No   Yes  Month-to-month     Yes    Yes   24
# 9    Male         0           No   Yes  Month-to-month     Yes     No   43
#
#        Salary     Base_pay       Bonus  Unit_Price    Volume  openingbalance  \
# ...

# %%
df.tail(10)
# Out:
#       Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 4990    Male         0           No   Yes  Month-to-month      No     No   70
# 4991    Male         1           No   Yes        Two year      No     No   70
# 4992    Male         1           No   Yes        One year      No     No   71
# 4993    Male         0           No   Yes  Month-to-month     Yes    Yes   71
# 4994    Male         0           No   Yes  Month-to-month     Yes     No   71
# 4995  Female         0           No   Yes  Month-to-month      No     No   72
# 4996    Male         0           No   Yes  Month-to-month     Yes     No   73
# 4997    Male         0           No   Yes  Month-to-month     Yes     No   74
# 4998    Male         1           No   Yes  Month-to-month     Yes    Yes   74
# 4999    Male         0          Yes   Yes        Two year     Yes     No   88
#
#            Salary     Base_pay        Bonus  Unit_Price   Volume  \
# ...

# %%
df.describe()
# Out:
#           Business          Age         Salary      Base_pay        Bonus  \
# count  5000.000000  5000.000000    5000.000000   4977.000000  5000.000000
# mean      0.160000    51.865000   99821.928553  40046.187707  4991.096428
# std       0.366643     8.560691   25376.961744  10135.686075  1268.848087
# min       0.000000    18.000000    5089.000000   2035.600000   254.450000
# 25%       0.000000    47.000000   83890.338980  33720.552420  4194.516950
# 50%       0.000000    52.000000  100579.378500  40282.016040  5028.968925
# 75%       0.000000    57.000000  116912.092475  46792.232410  5845.604624
# max       1.000000    88.000000  199970.740000  79988.296000  9998.537000
#
#         Unit_Price        Volume  openingbalance  closingbalance          low  \
# count  5000.000000  5.000000e+03     3524.000000     5000.000000  5000.000000
# mean     51.258522  6.761260e+06       43.922020       43.577828    43.034129
# ...

# %%
#filling empty cells of total_sales with nan
df=df.replace(r'^\s*$',float(np.NAN),regex=True)
df
# Out:
#       Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 0     Female         0           No   Yes  Month-to-month      No    Yes   18
# 1     Female         0           No   Yes  Month-to-month      No    Yes   19
# 2       Male         0           No   Yes  Month-to-month     Yes     No   22
# 3     Female         1           No   Yes  Month-to-month     Yes    Yes   21
# 4       Male         0           No   Yes  Month-to-month     Yes    Yes   23
# ...      ...       ...          ...   ...             ...     ...    ...  ...
# 4995  Female         0           No   Yes  Month-to-month      No     No   72
# 4996    Male         0           No   Yes  Month-to-month     Yes     No   73
# 4997    Male         0           No   Yes  Month-to-month     Yes     No   74
# 4998    Male         1           No   Yes  Month-to-month     Yes    Yes   74
# 4999    Male         0          Yes   Yes        Two year     Yes     No   88
#
# ...

# %%
df.tail() #to check weather that values are replaced with nan or not
# Out:
#       Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 4995  Female         0           No   Yes  Month-to-month      No     No   72
# 4996    Male         0           No   Yes  Month-to-month     Yes     No   73
# 4997    Male         0           No   Yes  Month-to-month     Yes     No   74
# 4998    Male         1           No   Yes  Month-to-month     Yes    Yes   74
# 4999    Male         0          Yes   Yes        Two year     Yes     No   88
#
#          Salary   Base_pay     Bonus  Unit_Price   Volume  openingbalance  \
# 4995  180696.80  72278.720  9034.840  629.511067  3927000             NaN
# 4996  185685.90  74274.360  9284.295  627.841071  6031900             NaN
# 4997  192636.80  77054.720  9631.840  625.860033  7949400             NaN
# 4998  195970.70  78388.280  9798.535  629.510005  3908400             NaN
# 4999  199970.74  79988.296  9998.537  627.839984  6003300             NaN
#
# ...

# %%
df.info()  #info tells types of data set
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          5000 non-null   object
#  1   Business        5000 non-null   int64
#  2   Dependancies    5000 non-null   object
#  3   Calls           5000 non-null   object
#  4   Type            5000 non-null   object
#  5   Billing         5000 non-null   object
#  6   Rating          5000 non-null   object
#  7   Age             5000 non-null   int64
#  8   Salary          5000 non-null   float64
#  9   Base_pay        4977 non-null   float64
#  10  Bonus           5000 non-null   float64
#  11  Unit_Price      5000 non-null   float64
#  12  Volume          5000 non-null   int64
#  13  openingbalance  3524 non-null   float64
#  14  closingbalance  5000 non-null   float64
#  15  low             5000 non-null   float64
#  16  Unit_Sales      5000 non-null   float64
# ...

# %%
df['Total_Sales']=df['Total_Sales'].astype('float64')  # changing data type of data sets
df
# Out:
#       Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 0     Female         0           No   Yes  Month-to-month      No    Yes   18
# 1     Female         0           No   Yes  Month-to-month      No    Yes   19
# 2       Male         0           No   Yes  Month-to-month     Yes     No   22
# 3     Female         1           No   Yes  Month-to-month     Yes    Yes   21
# 4       Male         0           No   Yes  Month-to-month     Yes    Yes   23
# ...      ...       ...          ...   ...             ...     ...    ...  ...
# 4995  Female         0           No   Yes  Month-to-month      No     No   72
# 4996    Male         0           No   Yes  Month-to-month     Yes     No   73
# 4997    Male         0           No   Yes  Month-to-month     Yes     No   74
# 4998    Male         1           No   Yes  Month-to-month     Yes    Yes   74
# 4999    Male         0          Yes   Yes        Two year     Yes     No   88
#
# ...

# %%
df.info()  # rechecking the information to confirm weather the data type of Total_Sales has changed or not
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          5000 non-null   object
#  1   Business        5000 non-null   int64
#  2   Dependancies    5000 non-null   object
#  3   Calls           5000 non-null   object
#  4   Type            5000 non-null   object
#  5   Billing         5000 non-null   object
#  6   Rating          5000 non-null   object
#  7   Age             5000 non-null   int64
#  8   Salary          5000 non-null   float64
#  9   Base_pay        4977 non-null   float64
#  10  Bonus           5000 non-null   float64
#  11  Unit_Price      5000 non-null   float64
#  12  Volume          5000 non-null   int64
#  13  openingbalance  3524 non-null   float64
#  14  closingbalance  5000 non-null   float64
#  15  low             5000 non-null   float64
#  16  Unit_Sales      5000 non-null   float64
# ...

# %%
missing_values=df.isnull().sum()  #counts the total number of nan value present in data set
missing_values
# Out:
# Gender               0
# Business             0
# Dependancies         0
# Calls                0
# Type                 0
# Billing              0
# Rating               0
# Age                  0
# Salary               0
# Base_pay            23
# Bonus                0
# Unit_Price           0
# Volume               0
# openingbalance    1476
# closingbalance       0
# low                  0
# Unit_Sales           0
# Total_Sales         16
# Months               0
# Education            0
# dtype: int64

# %%
#calculating percentage of missing values
total=df.isnull().sum().sort_values(ascending=False)       #total count of missing values per column 
percent_1=(df.isnull().sum()/df.shape[0])*100              #percentage of missing values per column
percent_2=round(percent_1,1).sort_values(ascending=False)  #percentage rounded to 1 decimal point

missing_data=pd.concat([total,percent_2],axis=1,keys=['Total','%'])  #concatenate the two series into a Datafeame
missing_data.head(3)  #displaying the top3 columns with missing data
# Out:
#                 Total     %
# openingbalance   1476  29.5
# Base_pay           23   0.5
# Total_Sales        16   0.3

# %%
from sklearn.impute import KNNImputer
x=df[['Base_pay','openingbalance','Total_Sales']]

#create an object
imputer=KNNImputer(n_neighbors=2)
#fit and transform the values
x=imputer.fit_transform(x)

# %%
#converting the array into dataframe
df[['Base_pay','openingbalance','Total_Sales']]=pd.DataFrame(x,columns=['Base_pay','openingbalance','Total_Sales'])

# %%
df.isna().sum()  #now checking again the sum of tool nan value present in the data set
# Out:
# Gender            0
# Business          0
# Dependancies      0
# Calls             0
# Type              0
# Billing           0
# Rating            0
# Age               0
# Salary            0
# Base_pay          0
# Bonus             0
# Unit_Price        0
# Volume            0
# openingbalance    0
# closingbalance    0
# low               0
# Unit_Sales        0
# Total_Sales       0
# Months            0
# Education         0
# dtype: int64

# %% [markdown]
# # EDA

# %%
#checking the total employee education wise
degree_wise=df.Education.value_counts()  #counting degree wise employee
degree_wise                              #degree wise employee
# Out:
# Education
# PG                     2979
# Graduation             1980
# Intermediate             27
# High School or less      14
# Name: count, dtype: int64

# %%
Gender_wise=df.Gender.value_counts()   #counting total number of the employee gender wise
Gender_wise                            #gender wise employee
# Out:
# Gender
# Male      2528
# Female    2472
# Name: count, dtype: int64

# %%
#counting how many employees have been rated by supervisor
Rating_wise=df.Rating.value_counts()  #counting the total number of ratings employee wise
Rating_wise                           #rating wise
# Out:
# Rating
# No     3682
# Yes    1318
# Name: count, dtype: int64

# %%
#counting how many employees authority to call
Call_wise=df.Calls.value_counts()  #counting the total number of employee who has authority to call
Call_wise                          #number of employee has authority to call
# Out:
# Calls
# Yes    4539
# No      461
# Name: count, dtype: int64

# %%
Dependancies_wise=df.Dependancies.value_counts() 
Dependancies_wise
# Out:
# Dependancies
# No     3524
# Yes    1476
# Name: count, dtype: int64

# %%
Age_wise=df.Age.value_counts()
Age_wise
# Out:
# Age
# 50    256
# 53    254
# 55    248
# 54    245
# 51    244
#      ...
# 78      2
# 80      1
# 82      1
# 85      1
# 79      1
# Name: count, Length: 65, dtype: int64

# %%
#checking count of salary settlement type
Type_wise=df.Type.value_counts()      #counting employee salary settlement type
Type_wise                             #no. of employee settlement type
# Out:
# Type
# Month-to-month    2777
# Two year          1195
# One year          1028
# Name: count, dtype: int64

# %%
#checking number of employee subscribed to billing plans or no
Billing_wise=df.Billing.value_counts()    #counting employee who has subscribed billing plans or not
Billing_wise                              #number of employee subscribed to billing plans
# Out:
# Billing
# Yes    2956
# No     2044
# Name: count, dtype: int64

# %%
#setting a grey background
sns.set(style="darkgrid")
#creating subplots with 10*10 figure size
fig,axs=plt.subplots(2,2,figsize=(10,10))
#ploting subplots with numerical variables
sns.histplot(data=df,x="Salary",kde=True,color="red",ax=axs[0,0])
sns.histplot(data=df,x="Base_pay",kde=True,color="olive",ax=axs[0,1])
sns.histplot(data=df,x="Bonus",kde=True,color="gold",ax=axs[1,0])
sns.histplot(data=df,x="Age",kde=True,color="black",ax=axs[1,1])
plt.show()

# %%
fig,axs=plt.subplots(1,2,figsize=(10,5))
#ploting subplots with numerical variables
sns.histplot(data=df,x="low",kde=True,color="red",ax=axs[0])  #histogram for low column
sns.histplot(data=df,x="Total_Sales",kde=True,color="Navy",ax=axs[1])   #histogram for Total_Sales
plt.show()

# %%
#setting a grey background
sns.set(style="darkgrid")
#creating subplots with 10*10 figure size
fig,axs=plt.subplots(2,2,figsize=(10,10))
#ploting subplots with variables
sns.boxplot(data=df,x="Salary",color="red",ax=axs[0,0])
sns.boxplot(data=df,x="Base_pay",color="olive",ax=axs[0,1])
sns.boxplot(data=df,x="Bonus",color="gold",ax=axs[1,0])
sns.boxplot(data=df,x="Age",color="black",ax=axs[1,1])
plt.show()

# %%
#setting a grey background
sns.set(style="darkgrid")
#creating subplots with 10*10 figure size
fig,axs=plt.subplots(2,2,figsize=(10,10))
#ploting subplots with variables
sns.boxplot(data=df,x="low",color="red",ax=axs[0,0])
sns.boxplot(data=df,x="Total_Sales",color="olive",ax=axs[0,1])
sns.boxplot(data=df,x="Volume",color="gold",ax=axs[1,0])
sns.boxplot(data=df,x="Months",color="black",ax=axs[1,1])
plt.show()

# %%
pip install pingouin
# Out:
# ...
#
# ...

# %%
#QQ plot for Salary
import pingouin as pg
pg.qqplot(df['Salary'],dist='norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %%
pg.qqplot(df['Base_pay'],dist='norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %%
pg.qqplot(df['Bonus'],dist='norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %%
pg.qqplot(df['Age'],dist='norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %%
pg.qqplot(df['low'],dist='norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %%
pg.qqplot(df['Total_Sales'],dist='norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %%
pg.qqplot(df['Months'],dist='norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %%
pg.qqplot(df['Volume'],dist='norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %%
pg.qqplot(df['Unit_Price'],dist='norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %%
pg.qqplot(df['openingbalance'],dist='norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %%
pg.qqplot(df['closingbalance'],dist='norm')
# Out:
# <Axes: xlabel='Theoretical quantiles', ylabel='Ordered quantiles'>

# %% [markdown]
# # finding out the correlation between variables using speearman rank correlation

# %%
#correlation
#person->whwn linearly correlated which is not possible
#spearsan->when data is not linearly distributed it is used
df3=df.drop(['Business'],axis=1)
df3.head()
# Out:
#    Gender Dependancies Calls            Type Billing Rating  Age   Salary  \
# 0  Female           No   Yes  Month-to-month      No    Yes   18  5089.00
# 1  Female           No   Yes  Month-to-month      No    Yes   19  5698.12
# 2    Male           No   Yes  Month-to-month     Yes     No   22  5896.65
# 3  Female           No   Yes  Month-to-month     Yes    Yes   21  6125.12
# 4    Male           No   Yes  Month-to-month     Yes    Yes   23  6245.00
#
#    Base_pay     Bonus  Unit_Price    Volume  openingbalance  closingbalance  \
# 0  2035.600  254.4500        3.77  21226600            3.75            3.76
# 1  2279.248  284.9060        3.74  10462800            3.85            3.68
# 2  2358.660  294.8325        3.89  18761000            4.23            4.29
# 3  2450.048  306.2560        4.35  66130600            4.26            4.31
# 4  2498.000  312.2500        4.34  26868200            4.79            4.41
#
#     low  Unit_Sales  Total_Sales  Months            Education
# ...

# %%
df3_numeric=df3.select_dtypes(include='number')

# %%
#spearman rank correlation heapmap
df3_numeric.corr(method="spearman") #selecting the method as a spearman
plt.figure(figsize=(20,8)) #setting the figuresize

heatmap=sns.heatmap(df3_numeric.corr(method='spearman').round(3),vmin=-1,
                                vmax=1,annot=True) # annot=True means writting the data value in each cell
font2={'family':'serif','color':'green','size':20}
plt.title("Spearman Rank Correlation",font2)
plt.show() #displayed heatmap

# %%
#looking the categorical columns
df.select_dtypes(include=['object']).columns.tolist()
# Out:
# ['Gender', 'Dependancies', 'Calls', 'Type', 'Billing', 'Rating', 'Education']

# %%
plt.figure(figsize=(9,8))  #size of the figure
sns.boxplot(data=df,x="Gender",y="Salary", color="Red")  #plotting the box plot for salary vs gender
plt.title("Salary vs Gender")  #plot title
# Out:
# Text(0.5, 1.0, 'Salary vs Gender')

# %%
plt.figure(figsize=(9,8))  #size of the figure
sns.boxplot(data=df,x="Education",y="Salary", color="green")  #plotting the box plot for salary vs education
plt.title("Salary vs Education")
# Out:
# Text(0.5, 1.0, 'Salary vs Education')

# %%
plt.figure(figsize=(9,8))  #size of the figure
sns.boxplot(data=df,x="Type",y="Salary", color="blue")  #plotting the box plot for salary vs type
plt.title("Salary vs Type")
# Out:
# Text(0.5, 1.0, 'Salary vs Type')

# %%
plt.figure(figsize=(9,8))  #size of the figure
sns.boxplot(data=df,x="Business",y="Salary", color="Red")  #plotting the box plot for salary vs business
plt.title("Salary vs Business ")
# Out:
# Text(0.5, 1.0, 'Salary vs Business ')

# %%
plt.figure(figsize=(9,8))  #size of the figure
sns.boxplot(data=df,x="Rating",y="Salary", color="pink")  #plotting the box plot for salary vs rating
plt.title("Salary vs Rating ")
# Out:
# Text(0.5, 1.0, 'Salary vs Rating ')

# %%
plt.figure(figsize=(9,8))  #size of the figure
sns.boxplot(data=df,x="Billing",y="Salary", color="Red")  #plotting the box plot for salary vs billing
plt.title("Salary vs Billing")
# Out:
# Text(0.5, 1.0, 'Salary vs Billing')

# %%
plt.figure(figsize=(9,8))  #size of the figure
sns.boxplot(data=df,x="Dependancies",y="Salary", color="black")  #plotting the box plot for salary vs Dependancies
plt.title("Salary vs Dependancies")
# Out:
# Text(0.5, 1.0, 'Salary vs Dependancies')

# %%
plt.figure(figsize=(9,8))  #size of the figure
sns.boxplot(data=df,x="Gender",y="Bonus", color="Red")  #plotting the box plot for bonus vs gender
plt.title("Bonus vs Gender")  #plot title
# Out:
# Text(0.5, 1.0, 'Bonus vs Gender')

# %%
plt.figure(figsize=(9,8))  #size of the figure
sns.boxplot(data=df,x="Education",y="Bonus", color="blue")  #plotting the box plot for bonus vs education
plt.title("Bonus vs Education")  #plot title
# Out:
# Text(0.5, 1.0, 'Bonus vs Education')

# %%
plt.figure(figsize=(9,8))  #size of the figure
sns.boxplot(data=df,x="Type",y="Bonus", color="blue")  #plotting the box plot for bonus vs type
plt.title("Bonus vs Type")  #plot title
# Out:
# Text(0.5, 1.0, 'Bonus vs Type')

# %%
plt.figure(figsize=(9,8))  #size of the figure
sns.boxplot(data=df,x="Business",y="Bonus", color="pink")  #plotting the box plot for bonus vs business
plt.title("Bonus vs Business")  #plot title
# Out:
# Text(0.5, 1.0, 'Bonus vs Business')

# %%
plt.figure(figsize=(9,8))  #size of the figure
sns.boxplot(data=df,x="Billing",y="Bonus", color="blue")  #plotting the box plot for bonus vs billing
plt.title("Bonus vs Billing")  #plot title
# Out:
# Text(0.5, 1.0, 'Bonus vs Billing')

# %%
plt.figure(figsize=(9,8))  #size of the figure
sns.boxplot(data=df,x="Dependancies",y="Bonus", color="blue")  #plotting the box plot for bonus vs Dependancies
plt.title("Bonus vs Dependancies")  #plot title
# Out:
# Text(0.5, 1.0, 'Bonus vs Dependancies')

# %%
#scatter plot vs salary and Base_pay
#distribution of salary on the basis of base_pay

plt.figure(figsize=(15,10))
plt.xlabel('Base_pay',fontsize=15)
plt.ylabel('salary',fontsize=15)
plt.title('Base_pay vs salary',fontsize=15)

sns.scatterplot(x=df['Base_pay'],y=df['Salary'],color='black')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.xlabel('Age',fontsize=15)
plt.ylabel('salary',fontsize=15)
plt.title('Age vs salary',fontsize=15)

sns.scatterplot(x=df['Age'],y=df['Salary'],color='black')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.xlabel('Volume',fontsize=15)
plt.ylabel('salary',fontsize=15)
plt.title('Volume vs salary',fontsize=15)

sns.scatterplot(x=df['Volume'],y=df['Salary'],color='black')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.xlabel('Unit_Price',fontsize=15)
plt.ylabel('salary',fontsize=15)
plt.title('Unit_Price vs salary',fontsize=15)

sns.scatterplot(x=df['Unit_Price'],y=df['Salary'],color='black')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.xlabel('low',fontsize=15)
plt.ylabel('salary',fontsize=15)
plt.title('low vs salary',fontsize=15)

sns.scatterplot(x=df['low'],y=df['Salary'],color='black')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.xlabel('openingbalance',fontsize=15)
plt.ylabel('salary',fontsize=15)
plt.title('openingbalance vs salary',fontsize=15)

sns.scatterplot(x=df['openingbalance'],y=df['Salary'],color='black')
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.xlabel('closingbalance',fontsize=15)
plt.ylabel('salary',fontsize=15)
plt.title('closingbalance vs salary',fontsize=15)

sns.scatterplot(x=df['closingbalance'],y=df['Salary'],color='black')
plt.show()

# %% [markdown]
# # checking outliers

# %%
plt.figure(figsize=(9,7)) #size of the figure
figure=df.boxplot(column="Age")  #box plot of the age

# %%
plt.figure(figsize=(9,7)) #size of the figure
figure=df.boxplot(column="Salary")

# %%
plt.figure(figsize=(9,7)) #size of the figure
figure=df.boxplot(column="Base_pay")

# %%
plt.figure(figsize=(9,7)) #size of the figure
figure=df.boxplot(column="Volume")

# %%
plt.figure(figsize=(9,7)) #size of the figure
figure=df.boxplot(column="Business")

# %%
plt.figure(figsize=(9,7)) #size of the figure
figure=df.boxplot(column="Bonus")

# %%
plt.figure(figsize=(9,7)) #size of the figure
figure=df.boxplot(column="Unit_Price")

# %%
plt.figure(figsize=(9,7)) #size of the figure
figure=df.boxplot(column="openingbalance")

# %%
plt.figure(figsize=(9,7)) #size of the figure
figure=df.boxplot(column="closingbalance")

# %%
plt.figure(figsize=(9,7)) #size of the figure
figure=df.boxplot(column="low")

# %%
plt.figure(figsize=(9,7)) #size of the figure
figure=df.boxplot(column="Unit_Sales")

# %%
plt.figure(figsize=(9,7)) #size of the figure
figure=df.boxplot(column="Months")

# %%
plt.figure(figsize=(9,7)) #size of the figure
figure=df.boxplot(column="Total_Sales")

# %%
# looking to the percentage of correlation
df3_numeric.corr(method='spearman')*100
# Out:
#                        Age      Salary    Base_pay       Bonus  Unit_Price  \
# Age             100.000000   20.228180   20.212073   20.228180   12.826637
# Salary           20.228180  100.000000   99.997589  100.000000   81.171311
# Base_pay         20.212073   99.997589  100.000000   99.997589   81.168113
# Bonus            20.228180  100.000000   99.997589  100.000000   81.171311
# Unit_Price       12.826637   81.171311   81.168113   81.171311  100.000000
# Volume           -3.934477  -39.048779  -39.042656  -39.048779  -32.422983
# openingbalance   -5.291931   45.346909   45.285139   45.346909   33.340773
# closingbalance   44.098882   34.649833   34.640860   34.649833   26.369923
# low              20.203950   99.985870   99.983405   99.985870   81.241207
# Unit_Sales       20.226808   99.999741   99.997324   99.999741   81.173482
# Total_Sales      20.217192   99.996492   99.994077   99.996492   81.170424
# ...

# %%
#dropping the non-required variables
dff=df.drop(columns=['Gender','Dependancies','Business','Calls','Type','Billing','Rating','Base_pay','Bonus','Unit_Price','Volume','openingbalance','closingbalance','low','Unit_Sales','Total_Sales'])
dff.head()
# Out:
#    Age   Salary  Months            Education
# 0   18  5089.00       0  High School or less
# 1   19  5698.12       0  High School or less
# 2   22  5896.65       0  High School or less
# 3   21  6125.12       0  High School or less
# 4   23  6245.00       1  High School or less

# %%
#label encoding to convert categorical data into numerical data

dff['Education']=dff['Education'].map({'High School or less':0,'Intermediate':1,'Graduation':2,'PG':3})
#assigning high school=0,intermediate=1 and gradaution=2

# %%
dff.head() #head of the data set after label encoding
# Out:
#    Age   Salary  Months  Education
# 0   18  5089.00       0          0
# 1   19  5698.12       0          0
# 2   22  5896.65       0          0
# 3   21  6125.12       0          0
# 4   23  6245.00       1          0

# %% [markdown]
# # handling outliers

# %%
Q1=dff.quantile(0.25).round(3)  #taking lower quantile into Q2
Q3=dff.quantile(0.75).round(3)  #taking upper quantile into Q3
IQR=Q3-Q1 #calculating inter quantile range
print(IQR) #printing quantile range
# Out:
# Age             10.000
# Salary       33021.753
# Months          47.000
# Education        1.000
# dtype: float64

# %%
dfout=dff[~((dff<(Q1-1.5*IQR))|(dff>(Q3+1.5*IQR))).any(axis=1)] #removing outliers
dfout.shape
# Out:
# (4833, 4)

# %% [markdown]
# # sanity check wheather outliers are removed or not

# %%
sns.boxplot(x=dfout['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
sns.boxplot(x=dfout['Salary'])
# Out:
# <Axes: xlabel='Salary'>

# %%
sns.boxplot(x=dfout['Months'])
# Out:
# <Axes: xlabel='Months'>

# %%
sns.boxplot(x=dfout['Education'])
# Out:
# <Axes: xlabel='Education'>

# %% [markdown]
# # Model Building

# %%
x=dff.drop(['Salary'],axis=1) #dropping highly co-related features
x #new datas set
# Out:
#       Age  Months  Education
# 0      18       0          0
# 1      19       0          0
# 2      22       0          0
# 3      21       0          0
# 4      23       1          0
# ...   ...     ...        ...
# 4995   72      72          3
# 4996   73      72          3
# 4997   74      72          3
# 4998   74      72          3
# 4999   88      72          3
#
# [5000 rows x 3 columns]

# %%
y=dff['Salary'] 
y
# Out:
# 0         5089.00
# 1         5698.12
# 2         5896.65
# 3         6125.12
# 4         6245.00
#           ...
# 4995    180696.80
# 4996    185685.90
# 4997    192636.80
# 4998    195970.70
# 4999    199970.74
# Name: Salary, Length: 5000, dtype: float64

# %%
#split x and y into training and testing sets
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
x_train
# Out:
#       Age  Months  Education
# 2858   45      21          2
# 1559   47       1          3
# 1441   45       1          3
# 2179   55       7          3
# 1390   44       1          2
# ...   ...     ...        ...
# 4931   63      72          3
# 3264   40      31          3
# 1653   48       2          2
# 2607   62      15          2
# 2732   68      18          2
#
# [3500 rows x 3 columns]

# %%
y_train
# Out:
# 2858    104938.82440
# 1559     88835.89005
# 1441     86903.28139
# 2179     96844.15570
# 1390     86096.55833
#             ...
# 4931    151880.35890
# 3264    110244.51700
# 1653     90043.98773
# 2607    101985.79940
# 2732    103369.50500
# Name: Salary, Length: 3500, dtype: float64

# %%
x_test
# Out:
#       Age  Months  Education
# 398    49      12          3
# 3833   39      48          2
# 4836   59      72          3
# 4572   51      68          3
# 636    53      27          3
# ...   ...     ...        ...
# 4554   50      68          3
# 4807   58      72          3
# 1073   64      63          3
# 2906   48      22          3
# 1357   43       1          3
#
# [1500 rows x 3 columns]

# %%
y_test
# Out:
# 398      64631.43297
# 3833    118137.14110
# 4836    143137.34650
# 4572    133346.50250
# 636      73049.74210
#             ...
# 4554    132723.77580
# 4807    141312.27900
# 1073     81265.54772
# 2906    105472.97890
# 1357     85510.67637
# Name: Salary, Length: 1500, dtype: float64

# %%
#data normalization with sklearn
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
#fit scalar on training data
x_train=sc.fit_transform(x_train)

#transform testing data
x_test=sc.transform(x_test)

# %%
x_train
# Out:
# array([[-0.79810913, -0.45185117, -1.14142217],
#        [-0.56643739, -1.26180691,  0.79882921],
#        [-0.79810913, -1.26180691,  0.79882921],
#        ...,
#        [-0.45060152, -1.22130912, -1.14142217],
#        [ 1.17110062, -0.69483789, -1.14142217],
#        [ 1.86611582, -0.57334453, -1.14142217]])

# %%
x_test
# Out:
# array([[-0.33476566, -0.81633125,  0.79882921],
#        [-1.49312433,  0.64158909, -1.14142217],
#        [ 0.82359302,  1.61353598,  0.79882921],
#        ...,
#        [ 1.40277236,  1.24905589,  0.79882921],
#        [-0.45060152, -0.41135338,  0.79882921],
#        [-1.02978086, -1.26180691,  0.79882921]])

# %% [markdown]
# # Machine learning technique

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error

#create and train the linear regression model
model_lr=LinearRegression()
model_lr.fit(x_train,y_train)

#Make predictions
y_pred_lr=model_lr.predict(x_test)

#calculate performance metrics
mae_lr=mean_absolute_error(y_test,y_pred_lr)
mse_lr=mean_squared_error(y_test,y_pred_lr)
rmse_lr=np.sqrt(mse_lr)
mape_lr=np.mean(np.abs((y_test - y_pred_lr)/np.abs(y_test)))
accuracy_lr=100*(1-mape_lr)

#print the performance metrics for linear regression
print('Linear Regression Metrics:')
print('Mean Absolute Error(MAE):',mae_lr)
print('Mean squared Error(MSE):',mse_lr)
print('Root Mean squared Error(RMSE):',rmse_lr)
print('Mean Absolute Percentage Error(MAPE):',round(mape_lr*100,2))
print('Accuracy:',round(accuracy_lr,2))
# Out:
# Linear Regression Metrics:
# Mean Absolute Error(MAE): 15319.356348066767
# Mean squared Error(MSE): 343537924.4925686
# Root Mean squared Error(RMSE): 18534.776084230652
# Mean Absolute Percentage Error(MAPE): 21.73
# Accuracy: 78.27

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error,mean_squared_error

#create and train the DecisionTreeRegressor model
model=DecisionTreeRegressor()
model.fit(x_train,y_train)

#Make predictions
y_pred=model.predict(x_test)

#calculate performance metrics
mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
rmse=np.sqrt(mse)
mape=np.mean(np.abs((y_test - y_pred)/np.abs(y_test)))
accuracy=100*(1-mape)

#print the performance metrics for DecisionTreeRegressor
print('Mean Absolute Error(MAE):',mae)
print('Mean squared Error(MSE):',mse)
print('Root Mean squared Error(RMSE):',rmse)
print('Mean Absolute Percentage Error(MAPE):',round(mape*100,2))
print('Accuracy:',round(accuracy,2))
# Out:
# Mean Absolute Error(MAE): 407.34652785233425
# Mean squared Error(MSE): 4733818.013094219
# Root Mean squared Error(RMSE): 2175.7339021797266
# Mean Absolute Percentage Error(MAPE): 0.65
# Accuracy: 99.35

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error,mean_squared_error

#create and train the  RandomForestRegressor model
model_rf= RandomForestRegressor(n_estimators=100,random_state=42)
model_rf.fit(x_train,y_train)

#Make predictions
y_pred_rf=model_rf.predict(x_test)

#calculate performance metrics
mae_rf=mean_absolute_error(y_test,y_pred_rf)
mse_rf=mean_squared_error(y_test,y_pred_rf)
rmse_rf=np.sqrt(mse_rf)
mape_rf=np.mean(np.abs((y_test - y_pred_rf)/np.abs(y_test)))
accuracy_rf=100*(1-mape_rf)

#print the performance metrics for  RandomForestRegressor
print('Random Forest Metrics:')
print('Mean Absolute Error(MAE):',mae_rf)
print('Mean squared Error(MSE):',mse_rf)
print('Root Mean squared Error(RMSE):',rmse_rf)
print('Mean Absolute Percentage Error(MAPE):',round(mape_rf*100,2))
print('Accuracy:',round(accuracy_rf,2))
# Out:
# Random Forest Metrics:
# Mean Absolute Error(MAE): 471.3135654212404
# Mean squared Error(MSE): 5406714.717223343
# Root Mean squared Error(RMSE): 2325.234335980643
# Mean Absolute Percentage Error(MAPE): 0.91
# Accuracy: 99.09

# %%
import xgboost as xgb
from sklearn.metrics import mean_absolute_error,mean_squared_error

#create and train the XGBoost model
model_xgb=xgb.XGBRegressor()
model_xgb.fit(x_train,y_train)

#Make predictions
y_pred_xgb=model_xgb.predict(x_test)

#calculate performance metrics
mae_xgb=mean_absolute_error(y_test,y_pred_xgb)
mse_xgb=mean_squared_error(y_test,y_pred_xgb)
rmse_xgb=np.sqrt(mse_xgb)
mape_xgb=np.mean(np.abs((y_test - y_pred_xgb)/np.abs(y_test)))
accuracy_xgb=100*(1-mape_xgb)

#print the performance metrics for XGBoost model
print('Mean Absolute Error(MAE):',mae_xgb)
print('Mean squared Error(MSE):',mse_xgb)
print('Root Mean squared Error(RMSE):',rmse_xgb)
print('Mean Absolute Percentage Error(MAPE):',round(mape_xgb*100,2))
print('Accuracy:',round(accuracy_xgb,2))
# Out:
# Mean Absolute Error(MAE): 497.28014051747914
# Mean squared Error(MSE): 5500086.227493529
# Root Mean squared Error(RMSE): 2345.2262636030514
# Mean Absolute Percentage Error(MAPE): 0.76
# Accuracy: 99.24

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Cross validation for our Model

# %%
#cross validation for our model
from sklearn.model_selection import ShuffleSplit,cross_val_score
model=LinearRegression()
ssplit=ShuffleSplit(n_splits=10,test_size=0.30)
from sklearn.model_selection import cross_val_score
results=cross_val_score(model,x,y,cv=ssplit)
print(results)
print("\nMean Cross-validation Accuracy:",np.mean(results))
# Out:
# [0.44080182 0.43681975 0.46030508 0.431339   0.46157573 0.48283858
#  0.44081794 0.48598144 0.42796197 0.43301033]
#
# Mean Cross-validation Accuracy: 0.45014516433328894

# %%
#cross validation for our model
from sklearn.model_selection import ShuffleSplit,cross_val_score
model=DecisionTreeRegressor(max_depth=3)
ssplit=ShuffleSplit(n_splits=10,test_size=0.30)
from sklearn.model_selection import cross_val_score
results=cross_val_score(model,x,y,cv=ssplit)
print(results)
print("\nMean Cross-validation Accuracy:",np.mean(results))
# Out:
# [0.57306935 0.59118285 0.52717594 0.69695495 0.52615002 0.5234148
#  0.54523099 0.60398272 0.52289122 0.49784595]
#
# Mean Cross-validation Accuracy: 0.5607898784787113

# %%
#cross validation for our model
from sklearn.model_selection import ShuffleSplit,cross_val_score
model=RandomForestRegressor(random_state=5)
ssplit=ShuffleSplit(n_splits=10,test_size=0.30)
from sklearn.model_selection import cross_val_score
results=cross_val_score(model,x,y,cv=ssplit)
print(results)
print("\nMean Cross-validation Accuracy:",np.mean(results))
# Out:
# [0.98469771 0.9904153  0.9847138  0.99164406 0.98724234 0.99062063
#  0.98929735 0.98555138 0.98832217 0.9912612 ]
#
# Mean Cross-validation Accuracy: 0.9883765927676107

# %%
model_xgb=xgb.XGBRegressor(objective='reg:squarederror',random_state=42)

#define ShuffleSplit cross-validation
ssplit=ShuffleSplit(n_splits=10,test_size=0.3)

#perform cross-validation
results_xgb=cross_val_score(model_xgb,x,y,cv=ssplit)

#print results for each field
print("Cross-validation results for each fold:")
print(results_xgb)

#print mean accuracy across all folds
print("\nMean Cross-validation Accuracy:",np.mean(results_xgb))
# Out:
# Cross-validation results for each fold:
# [0.99216028 0.98874226 0.98952052 0.98808901 0.9841887  0.98054047
#  0.9906021  0.98745691 0.99221758 0.98909523]
#
# Mean Cross-validation Accuracy: 0.9882613047563854

# %%
import pickle
from xgboost import XGBRegressor
# example: train a model (xgboost regressor as an example)
model_xgb=XGBRegressor()
model_xgb.fit(x_train,y_train)
# save the trained mode to a file usoing pickle
with open('hr.pkl','wb') as file:
    pickle.dump(model_xgb,file)
print("model saved successfull")
# Out:
# model saved successfull

# %%
with open('schr.pkl','wb') as scaler_file:
    pickle.dump(sc,scaler_file)

# %%
import tkinter as tk
import pickle
import numpy as np

# Load the trained XGBoost model
with open('hr.pkl', 'rb') as model_file:
    model = pickle.load(model_file)

# Load the scaler used during training
with open('schr.pkl', 'rb') as scaler_file:
    scaler = pickle.load(scaler_file)

# Create Tkinter GUI
root = tk.Tk()
root.title("Salary Prediction")

# Function to get prediction from input fields
def get_prediction():
    # Get input values from entry fields
    age = float(age_entry.get())
    experience = float(experience_entry.get())
    education = int(education_entry.get())

    # Create a numpy array with input values
    input_data = np.array([[age, experience, education]])

    # Normalize the input data using the scaler
    input_data_scaled = scaler.transform(input_data)

    # Predict using the loaded model
    prediction = model.predict(input_data_scaled)

    # Display prediction result
    result_label.config(text=f"Predicted Salary: ${prediction[0]:,.2f}")

# Create labels and entry fields for input features
tk.Label(root, text="Age").grid(row=0, column=0)
tk.Label(root, text="Experience (Months)").grid(row=1, column=0)
tk.Label(root, text="Education Level (0-3)").grid(row=2, column=0)

age_entry = tk.Entry(root)
experience_entry = tk.Entry(root)
education_entry = tk.Entry(root)

age_entry.grid(row=0, column=1)
experience_entry.grid(row=1, column=1)
education_entry.grid(row=2, column=1)

# Button to trigger prediction
predict_button = tk.Button(root, text="Predict", command=get_prediction)
predict_button.grid(row=3, columnspan=2)

# Label to display prediction result
result_label = tk.Label(root, text="")
result_label.grid(row=4, columnspan=2)

root.mainloop()

# %%
# Define the content of the updated Streamlit script
streamlit_code = """
import streamlit as st
import pickle
import numpy as np

# Load the trained XGBoost model and scaler
with open('hr.pkl', 'rb') as model_file:
    model = pickle.load(model_file)

with open('schr.pkl', 'rb') as scaler_file:
    scaler = pickle.load(scaler_file)

# Create the web app
st.title('Salary Prediction App')

# Input fields
age = st.number_input('Age', min_value=0, max_value=120, value=30)
education = st.selectbox('Education Level', ['High School or less', 'Intermediate', 'Graduation', 'PG'])
experience_months = st.number_input('Months of Experience', min_value=0, max_value=600, value=60)  # Assuming max experience is 50 years

# Convert education to numeric encoding
education_mapping = {'High School or less': 0, 'Intermediate': 1, 'Graduation': 2, 'PG': 3}
education_encoded = education_mapping[education]

# Prepare the feature vector
features = np.array([[age, education_encoded, experience_months]], dtype=np.float64)

# Scale the features
features_scaled = scaler.transform(features)

# Predict salary
predicted_salary = model.predict(features_scaled)

# Display the result
st.write(f"Predicted Salary: ${predicted_salary[0]:,.2f}")
"""

# Specify the file path where the hrapp.py file will be saved
file_path = 'hrapp.py'

# Write the content to the file
with open(file_path, 'w') as file:
    file.write(streamlit_code)

print(f"File '{file_path}' has been saved.")
